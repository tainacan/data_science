# %%
#Script para extrair arquivos de subpastas e mover para pasta principal

import os
import shutil

# %%
pasta = '/Users/daltonmartins/Downloads/MUSEU DO COLONO/fotografias'
for diretorio, subpastas, arquivos in os.walk(pasta):
    for subpasta in subpastas:
        #print(subpasta)
        for dire, sub, arqs in os.walk('/Users/daltonmartins/Downloads/MUSEU DO COLONO/fotografias/'+subpasta):
            for arquivo in arqs:
                print(arquivo)
                src_path = r'/Users/daltonmartins/Downloads/MUSEU DO COLONO/fotografias/'+subpasta+'/'+arquivo
                dst_path = r"/Users/daltonmartins/Downloads/MUSEU DO COLONO/"+arquivo
                shutil.move(src_path, dst_path)
                print('*')
# Out:
# 44.152.539.jpg
# *
# 44.149.521.jpg
# *
# 44.151.531.jpg
# *
# 44.151.536.jpg
# *
# 44.151.538.jpg
# *
# 43.145.504.jpg
# *
# 44.151.537.jpg
# *
# 44.150.530.jpg
# *
# 44.152.540_xerox da 470.jpg
# *
# 43.147.516.jpg
# *
# 43.147.518.jpg
# *
# 43.146.511.jpg
# *
# 43.147.517.jpg
# *
# 44.150.525.jpg
# *
# 43.146.510.jpg
# *
# 44.153.541.jpg
# *
# 44.155.547.jpg
# *
# 44.155.546.jpg
# *
# 43.144.498.jpg
# *
# 43.148.520.jpg
# *
# 44.151.535.jpg
# *
# 44.149.522.jpg
# *
# 44.151.532.jpg
# *
# 43.146.509.jpg
# *
# 43.145.501.jpg
# *
# 43.148.519.jpg
# *
# 43.146.508.jpg
# *
# 44.149.523.jpg
# *
# 44.151.533.jpg
# *
# 43.146.506.jpg
# *
# 44.149.524.jpg
# *
# 44.151.534.jpg
# *
# 43.146.512.jpg
# *
# 43.147.515.jpg
# *
# 44.150.527.jpg
# *
# 44.150.529.jpg
# *
# 44.153.542.jpg
# *
# 43.146.513.jpg
# *
# 44.150.528.jpg
# *
# 44.150.526.jpg
# *
# 30.56.189.jpg
# *
# 43.147.514.jpg
# *
# 44.154.543.jpg
# *
# 44.154.544.jpg
# *
# 44.155.545.jpg
# *
# MC.24.24.56_verso.jpg
# *
# ...

# %%
    for dire, sub, arqs in os.walk('/Users/daltonmartins/Downloads/MUSEU DO COLONO/'+subpasta):
            
            for file in arqs:
                origem="/Users/daltonmartins/Downloads/MUSEU DO COLONO/"+subpasta+"/"+sub+"/"+file
                src_path = r"/Users/daltonmartins/Downloads/MUSEU DO COLONO/"+subpasta+"/"+sub+"/"+file
                dst_path = r"/Users/daltonmartins/Downloads/MUSEU DO COLONO"+"/"+file
                shutil.move(src_path, dst_path)
                print('*')
