# %%
#Tutorial de apoio: https://towardsdatascience.com/scrape-data-from-pdf-files-using-python-and-pdfquery-d033721c3b28

import pdfquery
import pandas as pd
import re

# %%
pdf = pdfquery.PDFQuery('catalogo.pdf')
pdf.load(3)
pdf.tree.write('pdfXML.txt', pretty_print = True)

# %%
pdf.pq('LTTextLineHorizontal:overlaps_bbox("51.24, 662.38, 203.996, 674.74")').text()
# Out:
# 'Autor: Anais Toulouse'

# %%
pagecount = pdf.doc.catalog['Pages'].resolve()['Count']
documento=pd.DataFrame()
for p in range(pagecount):
    pdf.load(p)
    
    if p>=2 and p<51:
        autor=pdf.pq('LTTextLineHorizontal:overlaps_bbox("51.24, 662.38, 203.996, 674.74")').text()
        data=pdf.pq('LTTextLineHorizontal:overlaps_bbox("51.24, 641.02, 113.276, 653.38")').text()
        tematitulo=pdf.pq('LTTextLineHorizontal:overlaps_bbox("51.24, 619.78, 331.346, 632.14")').text()
        tecnica=pdf.pq('LTTextLineHorizontal:overlaps_bbox("51.24, 598.42, 207.986, 610.78")').text()
        dimensoes=pdf.pq('LTTextLineHorizontal:overlaps_bbox("51.24, 577.18, 332.906, 589.54")').text()
        local=pdf.pq('LTTextLineHorizontal:overlaps_bbox("51.24, 555.79, 246.146, 568.15")').text()
        patrimonio=pdf.pq('LTTextLineHorizontal:overlaps_bbox("51.24, 532.27, 115.316, 544.27")').text()
        descricao1=pdf.pq('LTTextLineHorizontal:overlaps_bbox("51.24, 510.79, 552.784, 523.15")').text()
        descricao2=pdf.pq('LTTextLineHorizontal:overlaps_bbox("51.36, 490.03, 523.678, 502.03")').text()
        descricao3=pdf.pq('LTTextLineHorizontal:overlaps_bbox("51.36, 469.15, 551.57, 481.15")').text()
        descricao4=pdf.pq('LTTextLineHorizontal:overlaps_bbox("51.36, 448.39, 276.146, 460.75")').text()
        
        if (autor==""):
            autor=pdf.pq('LTTextLineHorizontal:overlaps_bbox("46.08, 648.46, 239.546, 660.82")').text()
            data=pdf.pq('LTTextLineHorizontal:overlaps_bbox("46.08, 627.22, 448.366, 639.58")').text()
            tematitulo=pdf.pq('LTTextLineHorizontal:overlaps_bbox("46.08, 605.86, 224.786, 618.22")').text()
            tecnica=pdf.pq('LTTextLineHorizontal:overlaps_bbox("46.08, 584.62, 184.796, 596.98")').text()
            dimensoes=pdf.pq('LTTextLineHorizontal:overlaps_bbox("46.08, 563.23, 327.746, 575.59")').text()
            local=pdf.pq('LTTextLineHorizontal:overlaps_bbox("46.08, 541.99, 240.986, 554.35")').text()
            patrimonio=pdf.pq('LTTextLineHorizontal:overlaps_bbox("46.08, 520.87, 113.516, 532.87")').text()
            descricao1=pdf.pq('LTTextLineHorizontal:overlaps_bbox("46.08, 499.39, 295.466, 511.75")').text()
            descricao2=pdf.pq('LTTextLineHorizontal:overlaps_bbox("55.2, 471.67, 259.346, 484.03")').text()
            descricao3=""
            descricao4=""   
        
        page = pd.DataFrame({
                         'autor': autor,
                         'data': data,
                         'tematitulo': tematitulo,
                         'tecnica': tecnica,
                         'dimensoes': dimensoes,
                         'local': local,
                         'patrimonio': patrimonio,
                         'descricao': descricao1+" "+descricao2+" "+descricao3+" "+descricao4            
                       }, index=[p-2])
        documento = documento.append(page, ignore_index=True)
        
            
    elif p>=51:
        autor=pdf.pq('LTTextLineHorizontal:overlaps_bbox("43.44, 714.34, 219.626, 726.7")').text()
        data=pdf.pq('LTTextLineHorizontal:overlaps_bbox("43.44, 692.98, 135.476, 705.34")').text()
        tematitulo=pdf.pq('LTTextLineHorizontal:overlaps_bbox("43.44, 671.74, 302.906, 684.1")').text()
        tecnica=pdf.pq('LTTextLineHorizontal:overlaps_bbox("43.44, 650.38, 196.196, 662.74")').text()
        dimensoes=pdf.pq('LTTextLineHorizontal:overlaps_bbox("43.44, 629.14, 325.106, 641.5")').text()
        local=pdf.pq('LTTextLineHorizontal:overlaps_bbox("43.44, 607.78, 238.346, 620.14")').text()
        patrimonio=pdf.pq('LTTextLineHorizontal:overlaps_bbox("43.44, 586.78, 110.876, 598.78")').text()
        descricao1=pdf.pq('LTTextLineHorizontal:overlaps_bbox("43.44, 565.15, 543.512, 577.51")').text()
        descricao2=pdf.pq('LTTextLineHorizontal:overlaps_bbox("43.56, 544.39, 534.816, 556.39")').text()
        descricao3=pdf.pq('LTTextLineHorizontal:overlaps_bbox("43.56, 523.51, 179.636, 535.87")').text()
        descricao4=pdf.pq('LTTextLineHorizontal:overlaps_bbox("43.56, 495.07, 261.746, 507.07")').text() 
      
        page = pd.DataFrame({
                         'autor': autor,
                         'data': data,
                         'tematitulo': tematitulo,
                         'tecnica': tecnica,
                         'dimensoes': dimensoes,
                         'local': local,
                         'patrimonio': patrimonio,
                         'descricao': descricao1+" "+descricao2+" "+descricao3+" "+descricao4            
                       }, index=[p-2])
        documento = documento.append(page, ignore_index=True)
    else:
        print("Páginas iniciais")
# Out:
# Páginas iniciais
# Páginas iniciais

# %%
documento
# Out:
#                                 autor  \
# 0                 Autor: Adam Verdien
# 1               Autor: Anais Toulouse
# 2   Autor: Alcebiades Ghiu (Al. Ghiu)
# 3   Autor: Alcebiades Ghiu (Al. Ghiu)
# 4              Autor: Aldomário Pinto
# ..                                ...
# 81          Autor: Autor desconhecido
# 82          Autor: Autor desconhecido
# 83     Autor: Manufatura dos Gobelins
# 84     Autor: Manufatura dos Gobelins
# 85     Autor: Manufatura dos Gobelins
#
#                                                  data  \
# 0                                          Data: 1861
# 1                    Autor: Anais Toulouse Data: 1861
# 2   Data: 1945 (assinatura no canto inferior direi...
# 3   Data: 1945 (assinatura no canto inferior direi...
# 4   Data: Sem data (assinatura no canto inferior e...
# ..                                                ...
# 81                                     Data: Sem data
# 82                                     Data: Sem data
# ...

# %% [markdown]
# documento.to_excel("catalogopalacio.xlsx")

# %%
documento.to_excel("catalogopalacio.xlsx")
