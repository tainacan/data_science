# %%
#O objetivo do script é:

# 1. Identificar novas relações a partir da menção entre os acervos das informações: NOME DE PESSOAS, TÍTULO DE OBRAS
# NÚMERO DE REGISTRO, NOTAÇÃO/LOCALIZADOR E ASSUNTOS

# 2. Mapear as relações em formato de rede para analisar no GEPHI

# 3. Quantificar os relacionamentos e montar um relatório (fazer gráficos)

# %%
#Bibliotecas
import pandas as pd
import os

# %%
#variaveis de referencia a localização dos documentos

dir_documental='/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/acervo_documental_ALS/integracao/'
dir_fotografia='/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/acervos_fotografias_ALS/integracao/'
dir_obras='/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/acervos_obras_ALS/integracao/'

planilhas_documental=['RESPONSÁVEL.xlsx','RELACIONA-SE.xlsx','TRANSCRIÇÃO.xlsx','REFERÊNCIA.xlsx','HISTÓRICO.xlsx','ITEM AQUIVO.xlsx','ASSUNTO.xlsx']
planilhas_obras=['INSCRIÇÃO.xlsx','RELACIONA-SE.xlsx','TÍTULO.xlsx','ASSUNTO.xlsx']
planilhas_fotografias=['INSCRIÇÃO.xlsx','ITEM FOTOGRÁFIA.xlsx','RELACIONA-SE.xlsx','TRANSCRIÇÃO.xlsx','REFERÊNCIA.xlsx','ASSUNTO.xlsx']

# %%
#Cria dataframes para todas as tabelas

#OBRAS
obras_inscricao=pd.read_excel(dir_obras+'/'+'INSCRIÇÃO.xlsx')
obras_relaciona=pd.read_excel(dir_obras+'/'+'RELACIONA-SE.xlsx')
obras_titulo=pd.read_excel(dir_obras+'/'+'TÍTULO.xlsx')
obras_assunto=pd.read_excel(dir_obras+'/'+'ASSUNTO.xlsx')
obras_item=pd.read_excel(dir_obras+'/'+'ITEM MUSEU.xlsx')

#DOCUMENTAL
doc_responsavel=pd.read_excel(dir_documental+'/'+'RESPONSÁVEL.xlsx')
doc_relaciona=pd.read_excel(dir_documental+'/'+'RELACIONA-SE.xlsx')
doc_transcricao=pd.read_excel(dir_documental+'/'+'TRANSCRIÇÃO.xlsx')
doc_referencia=pd.read_excel(dir_documental+'/'+'REFERÊNCIA.xlsx')
doc_historico=pd.read_excel(dir_documental+'/'+'HISTÓRICO.xlsx')
doc_item=pd.read_excel(dir_documental+'/'+'ITEM ARQUIVO.xlsx')
doc_assunto=pd.read_excel(dir_documental+'/'+'ASSUNTO.xlsx')
doc_inscricao=pd.read_excel(dir_documental+'/'+'INSCRIÇÃO.xlsx')

#FOTOGRAFIA
foto_inscricao=pd.read_excel(dir_fotografia+'/'+'INSCRIÇÃO.xlsx')
foto_item=pd.read_excel(dir_fotografia+'/'+'ITEM FOTOGRÁFIA.xlsx')
foto_relaciona=pd.read_excel(dir_fotografia+'/'+'RELACIONA-SE.xlsx')
foto_transcricao=pd.read_excel(dir_fotografia+'/'+'TRANSCRIÇÃO.xlsx')
foto_referencia=pd.read_excel(dir_fotografia+'/'+'REFERÊNCIA.xlsx')
foto_assunto=pd.read_excel(dir_fotografia+'/'+'ASSUNTO.xlsx')

# %% [markdown]
# ### RELACIONAMENTOS ENTRE TÍTULO DE OBRAS -> DOCUMENTAL

# %%
#Busca pelo TITULO OBRAS no acervo DOCUMENTAL-INSCRICAO
df = pd.DataFrame(columns=['Registro Obra','Título','Registro Documento','Inscrição'])
for i in obras_titulo.index:
    
    #coleta string do titulo a buscar
    titulo=str(obras_titulo['título'][i])

    for x in doc_inscricao.index:
        
        #coleta string da inscrição a buscar
        inscricao=str(doc_inscricao['inscrição'][x])

        if inscricao.find(titulo)!=-1:
            dftemp=pd.DataFrame([[obras_titulo['número de registro'][i],titulo,doc_inscricao['notação/ localizador'][x],inscricao]], columns=['Registro Obra','Título','Registro Documento','Inscrição'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")

df.to_excel("/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/"+"REL-OBRAS-TITULO-DOC-INSCRICAO"+".xlsx",index=False)

# %%
#Busca pelo TITULO OBRAS no acervo DOCUMENTAL-TRANSCRICAO
df = pd.DataFrame(columns=['Registro Obra','Título','Registro Documento','Transcrição'])
for i in obras_titulo.index:
    
    #coleta string do titulo a buscar
    titulo=str(obras_titulo['título'][i])

    for x in doc_transcricao.index:
        
        #coleta string da trancrição a buscar
        transcricao=str(doc_transcricao['transcrição'][x])

        if transcricao.find(titulo)!=-1:
            dftemp=pd.DataFrame([[obras_titulo['número de registro'][i],titulo,doc_transcricao['notação/ localizador'][x],transcricao]], columns=['Registro Obra','Título','Registro Documento','Transcrição'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")

df.to_excel("/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/"+"REL-OBRAS-TITULO-DOC-TRANSCRICAO"+".xlsx",index=False)

# %%
#Busca pelo TITULO OBRAS no acervo DOCUMENTAL-ITEM ARQUIVO
df = pd.DataFrame(columns=['Registro Obra','Título','Registro Documento','Descrição','Resumo','Observações Gerais'])
for i in obras_titulo.index:
    
    #coleta string do titulo a buscar
    titulo=str(obras_titulo['título'][i])

    for x in doc_item.index:
        
        #coleta string da trancrição a buscar
        descricao=str(doc_item['descrição'][x])
        resumo=str(doc_item['resumo'][x])
        observacoes=str(doc_item['observações gerais'][x])

        if descricao.find(titulo)!=-1:
            dftemp=pd.DataFrame([[obras_titulo['número de registro'][i],titulo,doc_item['notação/ localizador'][x],descricao,'','']], columns=['Registro Obra','Título','Registro Documento','Descrição','Resumo','Observações Gerais'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")
            
        if resumo.find(titulo)!=-1:
            dftemp=pd.DataFrame([[obras_titulo['número de registro'][i],titulo,doc_item['notação/ localizador'][x],'',resumo,'']], columns=['Registro Obra','Título','Registro Documento','Descrição','Resumo','Observações Gerais'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")
            
        if observacoes.find(titulo)!=-1:
            dftemp=pd.DataFrame([[obras_titulo['número de registro'][i],titulo,doc_item['notação/ localizador'][x],'','',observacoes]], columns=['Registro Obra','Título','Registro Documento','Descrição','Resumo','Observações Gerais'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")

df.to_excel("/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/"+"REL-OBRAS-TITULO-DOC-ITEM"+".xlsx",index=False)

# %% [markdown]
# ### RELACIONAMENTOS ENTRE TÍTULO DE OBRAS -> FOTOGRAFIAS

# %%
#Busca pelo TITULO OBRAS no acervo FOTOGRAFIA-INSCRICAO
df = pd.DataFrame(columns=['Registro Obra','Título','Registro Fotografia','Inscrição','Nota'])
for i in obras_titulo.index:
    
    #coleta string do titulo a buscar
    titulo=str(obras_titulo['título'][i])

    for x in foto_inscricao.index:
        
        #coleta string da inscrição e notas a buscar
        inscricao=str(foto_inscricao['inscrição'][x])
        notas=str(foto_inscricao['notas'][x])

        if inscricao.find(titulo)!=-1:
            dftemp=pd.DataFrame([[obras_titulo['número de registro'][i],titulo,foto_inscricao['notação/ localizador'][x],inscricao,'']], columns=['Registro Obra','Título','Registro Fotografia','Inscrição','Nota'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")
            
        if notas.find(titulo)!=-1:
            dftemp=pd.DataFrame([[obras_titulo['número de registro'][i],titulo,foto_inscricao['notação/ localizador'][x],'',notas]], columns=['Registro Obra','Título','Registro Fotografia','Inscrição','Nota'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")

df.to_excel("/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/"+"REL-OBRAS-TITULO-FOTO-INSCRICAO"+".xlsx",index=False)

# %%
#Busca pelo TITULO OBRAS no acervo FOTOGRAFIA-ITEM FOTOGRAFIA
df = pd.DataFrame(columns=['Registro Obra','Título','Registro Fotografia','título/ denominação','observações gerais'])
for i in obras_titulo.index:
    
    #coleta string do titulo a buscar
    titulo=str(obras_titulo['título'][i])

    for x in foto_item.index:
        
        #coleta string da trancrição a buscar
        denominacao=str(foto_item['título/ denominação'][x])
        observacoes=str(foto_item['observações gerais'][x])

        if denominacao.find(titulo)!=-1:
            dftemp=pd.DataFrame([[obras_titulo['número de registro'][i],titulo,foto_item['notação/ localizador'][x],denominacao,'']], columns=['Registro Obra','Título','Registro Fotografia','título/ denominação','observações gerais'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")
            
        if observacoes.find(titulo)!=-1:
            dftemp=pd.DataFrame([[obras_titulo['número de registro'][i],titulo,foto_item['notação/ localizador'][x],'',observacoes]], columns=['Registro Obra','Título','Registro Fotografia','título/ denominação','observações gerais'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")

df.to_excel("/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/"+"REL-OBRAS-TITULO-FOTO-ITEM"+".xlsx",index=False)

# %%
#Busca pelo TITULO OBRAS no acervo FOTOGRAFIA-TRANSCRICAO
df = pd.DataFrame(columns=['Registro Obra','Título','Registro Fotografia','Transcrição'])
for i in obras_titulo.index:
    
    #coleta string do titulo a buscar
    titulo=str(obras_titulo['título'][i])

    for x in foto_transcricao.index:
        
        #coleta string da trancrição a buscar
        transcricao=str(foto_transcricao['transcrição'][x])

        if transcricao.find(titulo)!=-1:
            dftemp=pd.DataFrame([[obras_titulo['número de registro'][i],titulo,foto_transcricao['notação/ localizador'][x],transcricao]], columns=['Registro Obra','Título','Registro Fotografia','Transcrição'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")

df.to_excel("/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/"+"REL-OBRAS-TITULO-FOTO-TRANSCRICAO"+".xlsx",index=False)

# %%
#Busca pelo TITULO OBRAS no acervo FOTOGRAFIA-REFERENCIA
df = pd.DataFrame(columns=['Registro Obra','Título','Registro Fotografia','Descrição'])
for i in obras_titulo.index:
    
    #coleta string do titulo a buscar
    titulo=str(obras_titulo['título'][i])

    for x in foto_referencia.index:
        
        #coleta string da trancrição a buscar
        descricao=str(foto_referencia['descrição'][x])

        if descricao.find(titulo)!=-1:
            dftemp=pd.DataFrame([[obras_titulo['número de registro'][i],titulo,foto_referencia['notação/ localizador'][x],descricao]], columns=['Registro Obra','Título','Registro Fotografia','Descrição'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")

df.to_excel("/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/"+"REL-OBRAS-TITULO-FOTO-REFERENCIA"+".xlsx",index=False)

# %% [markdown]
# ### RELACIONAMENTO ENTRE OS ACERVOS POR ASSUNTO

# %%
#Busca pelo ASSUNTO OBRAS NOS ASSUNTOS DOCUMENTAL
df = pd.DataFrame(columns=['Registro Obra','Assunto','Registro Documento','Assunto'])
for i in obras_assunto.index:
    
    #coleta string do assunto a buscar
    assunto_obras=str(obras_assunto['assunto'][i])

    for x in doc_assunto.index:
        
        #coleta string do assunto a buscar
        assunto_doc=str(doc_assunto['assunto'][x])

        if assunto_doc.find(assunto_obras)!=-1:
            dftemp=pd.DataFrame([[obras_assunto['número de registro'][i],assunto_obras,doc_assunto['notação/ localizador'][x],assunto_doc]], columns=['Registro Obra','Assunto','Registro Documento','Assunto'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")

df.to_excel("/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/"+"REL-OBRAS-ASSUNTO-DOC-ASSUNTO"+".xlsx",index=False)

# %%
#Busca pelo ASSUNTO OBRAS NOS ASSUNTOS FOTOGRAFIA
df = pd.DataFrame(columns=['Registro Obra','Assunto','Registro Fotografia','Assunto'])
for i in obras_assunto.index:
    
    #coleta string do assunto a buscar
    assunto_obras=str(obras_assunto['assunto'][i])

    for x in foto_assunto.index:
        
        #coleta string do assunto a buscar
        assunto_foto=str(foto_assunto['assunto'][x])

        if assunto_foto.find(assunto_obras)!=-1:
            dftemp=pd.DataFrame([[obras_assunto['número de registro'][i],assunto_obras,foto_assunto['notação/ localizador'][x],assunto_foto]], columns=['Registro Obra','Assunto','Registro Fotografia','Assunto'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")

df.to_excel("/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/"+"REL-OBRAS-ASSUNTO-FOTO-ASSUNTO"+".xlsx",index=False)

# %% [markdown]
# ### RELACIONAMENTOS ENTRE NÚMERO DE OBRAS -> DOCUMENTAL

# %%
#Busca pelo NÚMERO DE OBRAS no acervo DOCUMENTAL-INSCRICAO
df = pd.DataFrame(columns=['Registro Obra','Registro Documento','Inscrição'])
for i in obras_item.index:
    
    #coleta string do REGISTRO a buscar
    registro=str(obras_item['número de registro'][i])
    registroup=registro.upper()

    for x in doc_inscricao.index:
        
        #coleta string da inscrição a buscar
        inscricao=str(doc_inscricao['inscrição'][x])

        if inscricao.find(registro)!=-1 or inscricao.find(registroup)!=-1:
            dftemp=pd.DataFrame([[obras_item['número de registro'][i],doc_inscricao['notação/ localizador'][x],inscricao]], columns=['Registro Obra','Registro Documento','Inscrição'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")

df.to_excel("/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/"+"REL-OBRAS-REGISTRO-DOC-INSCRICAO"+".xlsx",index=False)

# %%
#Busca pelo NÚMERO OBRAS no acervo DOCUMENTAL-TRANSCRICAO
df = pd.DataFrame(columns=['Registro Obra','Registro Documento','Transcrição'])
for i in obras_item.index:
    
    #coleta string do REGISTRO a buscar
    registro=str(obras_item['número de registro'][i])
    registroup=registro.upper()


    for x in doc_transcricao.index:
        
        #coleta string da trancrição a buscar
        transcricao=str(doc_transcricao['transcrição'][x])

        if transcricao.find(registro)!=-1 or transcricao.find(registroup)!=-1:
            dftemp=pd.DataFrame([[obras_item['número de registro'][i],doc_transcricao['notação/ localizador'][x],transcricao]], columns=['Registro Obra','Registro Documento','Transcrição'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")

df.to_excel("/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/"+"REL-OBRAS-REGISTRO-DOC-TRANSCRICAO"+".xlsx",index=False)

# %%
#Busca pelo REGISTRO OBRAS no acervo DOCUMENTAL-ITEM ARQUIVO
df = pd.DataFrame(columns=['Registro Obra','Registro Documento','Descrição','Resumo','Observações Gerais'])
for i in obras_item.index:
    
    #coleta string do REGISTRO a buscar
    registro=str(obras_item['número de registro'][i])
    registroup=registro.upper()

    for x in doc_item.index:
        
        #coleta string da trancrição a buscar
        descricao=str(doc_item['descrição'][x])
        resumo=str(doc_item['resumo'][x])
        observacoes=str(doc_item['observações gerais'][x])

        if descricao.find(registro)!=-1 or descricao.find(registroup)!=-1:
            dftemp=pd.DataFrame([[obras_item['número de registro'][i],doc_item['notação/ localizador'][x],descricao,'','']], columns=['Registro Obra','Registro Documento','Descrição','Resumo','Observações Gerais'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")
            
        if resumo.find(registro)!=-1 or resumo.find(registroup)!=-1:
            dftemp=pd.DataFrame([[obras_item['número de registro'][i],doc_item['notação/ localizador'][x],'',resumo,'']], columns=['Registro Obra','Registro Documento','Descrição','Resumo','Observações Gerais'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")
            
        if observacoes.find(registro)!=-1 or observacoes.find(registroup)!=-1:
            dftemp=pd.DataFrame([[obras_item['número de registro'][i],doc_item['notação/ localizador'][x],'','',observacoes]], columns=['Registro Obra','Registro Documento','Descrição','Resumo','Observações Gerais'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")

df.to_excel("/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/"+"REL-OBRAS-REGISTRO-DOC-ITEM"+".xlsx",index=False)

# %% [markdown]
# ### RELACIONAMENTOS ENTRE NÚMERO DE OBRAS -> FOTOGRAFIA

# %%
#Busca pelo REGISTRO OBRAS no acervo FOTOGRAFIA-INSCRICAO
df = pd.DataFrame(columns=['Registro Obra','Registro Fotografia','Inscrição','Nota'])
for i in obras_item.index:
    
    #coleta string do REGISTRO a buscar
    registro=str(obras_item['número de registro'][i])
    registroup=registro.upper()

    for x in foto_inscricao.index:
        
        #coleta string da inscrição e notas a buscar
        inscricao=str(foto_inscricao['inscrição'][x])
        notas=str(foto_inscricao['notas'][x])

        if inscricao.find(registro)!=-1 or inscricao.find(registroup)!=-1:
            dftemp=pd.DataFrame([[obras_item['número de registro'][i],foto_inscricao['notação/ localizador'][x],inscricao,'']], columns=['Registro Obra','Registro Fotografia','Inscrição','Nota'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")
            
        if notas.find(registro)!=-1 or notas.find(registroup)!=-1:
            dftemp=pd.DataFrame([[obras_item['número de registro'][i],foto_inscricao['notação/ localizador'][x],'',notas]], columns=['Registro Obra','Registro Fotografia','Inscrição','Nota'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")

df.to_excel("/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/"+"REL-OBRAS-REGISTRO-FOTO-INSCRICAO"+".xlsx",index=False)

# %%
#Busca pelo REGISTRO OBRAS no acervo FOTOGRAFIA-ITEM
df = pd.DataFrame(columns=['Registro Obra','Registro Fotografia','título/ denominação','observações gerais'])
for i in obras_item.index:
    
    #coleta string do REGISTRO a buscar
    registro=str(obras_item['número de registro'][i])
    registroup=registro.upper()

    for x in foto_item.index:
        
        #coleta string da trancrição a buscar
        denominacao=str(foto_item['título/ denominação'][x])
        observacoes=str(foto_item['observações gerais'][x])

        if denominacao.find(registro)!=-1 or denominacao.find(registroup)!=-1:
            dftemp=pd.DataFrame([[obras_item['número de registro'][i],foto_item['notação/ localizador'][x],denominacao,'']], columns=['Registro Obra','Registro Fotografia','título/ denominação','observações gerais'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")
            
        if observacoes.find(registro)!=-1 or observacoes.find(registroup)!=-1:
            dftemp=pd.DataFrame([[obras_item['número de registro'][i],foto_item['notação/ localizador'][x],'',observacoes]], columns=['Registro Obra','Registro Fotografia','título/ denominação','observações gerais'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")

df.to_excel("/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/"+"REL-OBRAS-REGISTRO-FOTO-ITEM"+".xlsx",index=False)

# %%
#Busca pelo REGISTRO OBRAS no acervo FOTOGRAFIA-TRANSCRICAO
df = pd.DataFrame(columns=['Registro Obra','Registro Fotografia','Transcrição'])
for i in obras_item.index:
    
    #coleta string do REGISTRO a buscar
    registro=str(obras_item['número de registro'][i])
    registroup=registro.upper()

    for x in foto_transcricao.index:
        
        #coleta string da trancrição a buscar
        transcricao=str(foto_transcricao['transcrição'][x])

        if transcricao.find(registro)!=-1 or transcricao.find(registroup)!=-1:
            dftemp=pd.DataFrame([[obras_item['número de registro'][i],foto_transcricao['notação/ localizador'][x],transcricao]], columns=['Registro Obra','Registro Fotografia','Transcrição'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")

df.to_excel("/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/"+"REL-OBRAS-REGISTRO-FOTO-TRANSCRICAO"+".xlsx",index=False)

# %%
#Busca pelo REGISTRO OBRAS no acervo FOTOGRAFIA-REFERENCIA
df = pd.DataFrame(columns=['Registro Obra','Registro Fotografia','Descrição'])
for i in obras_item.index:
    
    #coleta string do REGISTRO a buscar
    registro=str(obras_item['número de registro'][i])
    registroup=registro.upper()

    for x in foto_referencia.index:
        
        #coleta string da trancrição a buscar
        descricao=str(foto_referencia['descrição'][x])

        if descricao.find(registro)!=-1 or descricao.find(registroup)!=-1:
            dftemp=pd.DataFrame([[obras_item['número de registro'][i],foto_referencia['notação/ localizador'][x],descricao]], columns=['Registro Obra','Registro Fotografia','Descrição'])
            df = df.append(dftemp, ignore_index=True)
            #print(".",end="")

df.to_excel("/Users/daltonmartins/Library/CloudStorage/OneDrive-unb.br/Scripts/Modelagem Museu Lasar Segall/"+"REL-OBRAS-REGISTRO-FOTO-REFERENCIA"+".xlsx",index=False)

# %% [markdown]
# ### Filtra relacoes

# %%
arquivos=['REL-OBRAS-TITULO-DOC-INSCRICAO.xlsx','REL-OBRAS-TITULO-DOC-TRANSCRICAO.xlsx','REL-OBRAS-TITULO-DOC-ITEM.xlsx','REL-OBRAS-TITULO-FOTO-INSCRICAO.xlsx','REL-OBRAS-TITULO-FOTO-ITEM.xlsx','REL-OBRAS-TITULO-FOTO-TRANSCRICAO.xlsx','REL-OBRAS-TITULO-FOTO-REFERENCIA.xlsx','REL-OBRAS-ASSUNTO-DOC-ASSUNTO.xls','REL-OBRAS-ASSUNTO-FOTO-ASSUNTO.xls']
arquivos
# Out:
# ['REL-OBRAS-TITULO-DOC-INSCRICAO.xlsx',
#  'REL-OBRAS-TITULO-DOC-TRANSCRICAO.xlsx',
#  'REL-OBRAS-TITULO-DOC-ITEM.xlsx',
#  'REL-OBRAS-TITULO-FOTO-INSCRICAO.xlsx',
#  'REL-OBRAS-TITULO-FOTO-ITEM.xlsx',
#  'REL-OBRAS-TITULO-FOTO-TRANSCRICAO.xlsx',
#  'REL-OBRAS-TITULO-FOTO-REFERENCIA.xlsx',
#  'REL-OBRAS-ASSUNTO-DOC-ASSUNTO.xls',
#  'REL-OBRAS-ASSUNTO-FOTO-ASSUNTO.xls']

# %%
for arquivo in arquivos:
    df=pd.read_excel(arquivo)

    '''
    if arquivo=='REL-OBRAS-TITULO-FOTO-ITEM.xlsx':
        print(arquivo)
        
        print(df.index.size)
        for i in df.index:
            titulo=str(df['Título'][i])
            descricao=str(df['título/ denominação'][i])
            resumo=str(df['observações gerais'][i])
    
            if descricao!='nan':
                pos=descricao.index(titulo)
                if (pos>0):
                    if len(descricao)>pos+len(titulo):
                        if descricao[pos-1]!=' ' or descricao[pos+len(titulo)]!=' ':
                            df = df.drop(i)
                    elif descricao[pos-1]!=' ':
                        df = df.drop(i)                    
                elif len(descricao)>len(titulo):
                    if descricao[pos+len(titulo)]!=' ':
                        df = df.drop(i)
            elif resumo!='nan': 
                pos=resumo.index(titulo)
                if (pos>0):
                    if len(resumo)>pos+len(titulo):
                        if resumo[pos-1]!=' ' or resumo[pos+len(titulo)]!=' ':
                            df = df.drop(i)
                    elif resumo[pos-1]!=' ':
                        df = df.drop(i)                    
                elif len(resumo)>len(titulo):
                    if resumo[pos+len(titulo)]!=' ':
                        df = df.drop(i)
             
        print(df.index.size)
        df.to_excel("FILTRO_"+arquivo,index=False)         
    
    '''
    
       
    if arquivo=='REL-OBRAS-ASSUNTO-FOTO-ASSUNTO.xls':
        print(arquivo)
              
        print(df.index.size)
        for i in df.index:
            titulo=str(df['Assunto'][i])
            inscricao=str(df['Assunto1'][i])
            pos=inscricao.index(titulo)
            if (pos>0):
                if len(inscricao)>pos+len(titulo):
                    if inscricao[pos-1]!=' ' or inscricao[pos+len(titulo)]!=' ':
                        df = df.drop(i)
                elif inscricao[pos-1]!=' ':
                    df = df.drop(i)                    
            elif len(inscricao)>len(titulo):
                if inscricao[pos+len(titulo)]!=' ':
                    df = df.drop(i)
        print(df.index.size)
        df.to_excel("FILTRO_"+arquivo,index=False) 
       
    
    '''
    if arquivo=='REL-OBRAS-TITULO-FOTO-INSCRICAO.xlsx':
        print(arquivo)
        
        print(df.index.size)
        for i in df.index:
            titulo=str(df['Título'][i])
            nota=str(df['Nota'][i])
            inscricao=str(df['Inscrição'][i])
            if inscricao!='nan':

                pos=inscricao.index(titulo)
                if (pos>0):
                    if len(inscricao)>pos+len(titulo):
                        if inscricao[pos-1]!=' ' or inscricao[pos+len(titulo)]!=' ':
                            df = df.drop(i)
                    elif inscricao[pos-1]!=' ':
                        df = df.drop(i)                    
                elif len(inscricao)>len(titulo):
                    if inscricao[pos+len(titulo)]!=' ':
                        df = df.drop(i)
            else: 
                pos=nota.index(titulo)
                if (pos>0):
                    if len(nota)>pos+len(titulo):
                        if nota[pos-1]!=' ' or nota[pos+len(titulo)]!=' ':
                            df = df.drop(i)
                    elif nota[pos-1]!=' ':
                        df = df.drop(i)                    
                elif len(nota)>len(titulo):
                    if nota[pos+len(titulo)]!=' ':
                        df = df.drop(i)
        print(df.index.size)
        df.to_excel("FILTRO_"+arquivo,index=False)         

    '''                    
    '''
    if arquivo=='REL-OBRAS-TITULO-DOC-TRANSCRICAO.xlsx':
        print(arquivo)
        
        print(df.index.size)
        
        for i in df.index:
            titulo=str(df['Título'][i])
            inscricao=str(df['Transcrição'][i])
            pos=inscricao.index(titulo)
            if (pos>0):
                if len(inscricao)>pos+len(titulo):
                    if inscricao[pos-1]!=' ' or inscricao[pos+len(titulo)]!=' ':
                        df = df.drop(i)
                elif inscricao[pos-1]!=' ':
                    df = df.drop(i)                    
            elif len(inscricao)>len(titulo):
                if inscricao[pos+len(titulo)]!=' ':
                    df = df.drop(i)
        print(df.index.size)
        df.to_excel("FILTRO_"+arquivo,index=False)                           
    '''
'''
    elif 'Resumo' in colunas:
        print('Arquivo Item Documental')
    elif 'observações gerais' in colunas:
        print('Arquivo Item Fotografia')
    elif 'Descrição' in colunas:
        print('Arquivo Referencia')
    elif 'Assunto' in colunas:
        print('Arquivo Assunto')
'''
# Out:
# REL-OBRAS-ASSUNTO-FOTO-ASSUNTO.xls
# 36049
# 32463
# /var/folders/jj/x5mdy7jn5nq5wn3g__n81hd40000gn/T/ipykernel_68471/3967928180.py:61: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel("FILTRO_"+arquivo,index=False)
# "\n    elif 'Resumo' in colunas:\n        print('Arquivo Item Documental')\n    elif 'observações gerais' in colunas:\n        print('Arquivo Item Fotografia')\n    elif 'Descrição' in colunas:\n        print('Arquivo Referencia')\n    elif 'Assunto' in colunas:\n        print('Arquivo Assunto')\n"

# %%
string1="Dalton Lopes Martins"
pos=string1.index('Lopes')
if string1[pos+len('Lopes')+1]=='M':
    print('Certo!')
# Out:
# Certo!
